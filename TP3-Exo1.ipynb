# %%
from scipy.io import wavfile
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import find_peaks
import numpy as np
import matplotlib.pyplot as plt
from adjustText import adjust_text
from spectrum import *
# The Periodogram class provides an interface to periodogram PSDs // Normalized frequency (w/pi)
fs, data1 = wavfile.read("noise1.wav")
data1=data1.astype(np.float)
fs2, data2 = wavfile.read("noise2.wav")
data=data.astype(np.float)
fs3, data3 = wavfile.read("noise3.wav")
data=data.astype(np.float)
p = Periodogram(data1)
p()
p.plot()

plt.title('Periodogram for noise 1')
# Out:
# Text(0.5, 1.0, 'Periodogram for noise 1')

# %%
from spectrum import *
psd = WelchPeriodogram(data1, data1.size)

plt.title('WelshPeriodogram for noise 1')
# Out:
# Text(0.5, 1.0, 'WelshPeriodogram for noise 1')

# %%
from spectrum import *
p = Periodogram(data2)
p()
p.plot()
plt.title('Periodogram for noise 2')
# Out:
# Text(0.5, 1.0, 'Periodogram for noise 2')

# %%
psd = WelchPeriodogram(data2, data2.size)

plt.title('WelshPeriodogram for noise 2')
# Out:
# Text(0.5, 1.0, 'WelshPeriodogram for noise 2')

# %%
p = Periodogram(data3)
p()
p.plot()
plt.title('Periodogram for noise 3')
# Out:
# Text(0.5, 1.0, 'Periodogram for noise 3')

# %%
psd2 = WelchPeriodogram(data3, data3.size)
plt.title('WelshPeriodogram for noise 3')
# Out:
# Text(0.5, 1.0, 'WelshPeriodogram for noise 3')

# %%
from scipy import signal
freqs, times, spectrogram = signal.spectrogram(data)
plt.figure(figsize=(5, 4))
plt.imshow(spectrogram, aspect='auto', cmap='hot_r', origin='lower')
plt.title('Spectrogram')
plt.ylabel('Frequency band')
plt.xlabel('Time window')

plt.title('Speectogram noise 1')
plt.tight_layout()
